# %%
import pandas as pd
from datetime import datetime, timedelta
import datetime as dt
import psycopg2
from psycopg2 import OperationalError

# %%
date = datetime.date(datetime.today())

print(f"{date}")
# Out:
# 2025-04-25

# %%
def create_connection(db_name, db_user, db_password, db_host, db_port):
    connection = None
    try:
        connection = psycopg2.connect(
            database=db_name,
            user=db_user,
            password=db_password,
            host=db_host,
            port=db_port,
        )
        print("Conexão com o PostgreSQL bem-sucedida")
    except OperationalError as e:
        print(f"O erro '{e}' ocorreu")
    return connection

# %%
connection = create_connection(
    "api_django", "api_django", "31032018", "34.121.153.167", "5432"
)

def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        print("Query executada com sucesso")
    except OperationalError as e:
        print(f"O erro '{e}' ocorreu")
# Out:
# Conexão com o PostgreSQL bem-sucedida

# %%
query = """
SELECT 
    id_venda_item, 
    id_venda, 
    data_venda, 
    data_envio,
    tipo_envio, 
    id_cliente, 
    nome_cliente, 
    segmento, 
    pais, 
    cidade, 
    estado, 
    codigo_postal, 
    regiao, 
    id_produto, 
    descricao_produto, 
    categoria_produto, 
    subcategoria_produto, 
    valor_venda, 
    quantidade_vendida, 
    desconto, 
    margem
FROM public.api_integration;
"""

# %%
cursor = connection.cursor()

# %%
cursor.execute(query)
df = cursor.fetchall()

# %%
columns = [desc[0] for desc in cursor.description]
df
# Out:
# [(11497,
#   'CA-2016-152156',
#   datetime.date(2016, 11, 8),
#   datetime.date(2016, 11, 11),
#   'Second Class',
#   'CG-12520',
#   'Claire Gute',
#   'Consumer',
#   'United States',
#   'Henderson',
#   'Kentucky',
#   '42420',
#   'South',
#   'FUR-BO-10001798',
#   'Bush Somerset Collection Bookcase',
#   'Furniture',
#   'Bookcases',
#   Decimal('261.9600000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('41.9136000000')),
#  (11498,
#   'CA-2016-152156',
#   datetime.date(2016, 11, 8),
#   datetime.date(2016, 11, 11),
#   'Second Class',
#   'CG-12520',
#   'Claire Gute',
#   'Consumer',
#   'United States',
#   'Henderson',
#   'Kentucky',
#   '42420',
#   'South',
#   'FUR-CH-10000454',
#   'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back',
#   'Furniture',
#   'Chairs',
#   Decimal('731.9400000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('219.5820000000')),
#  (11499,
#   'CA-2016-138688',
#   datetime.date(2016, 6, 12),
#   datetime.date(2016, 6, 16),
#   'Second Class',
#   'DV-13045',
#   'Darrin Van Huff',
#   'Corporate',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90036',
#   'West',
#   'OFF-LA-10000240',
#   'Self-Adhesive Address Labels for Typewriters by Universal',
#   'Office Supplies',
#   'Labels',
#   Decimal('14.6200000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('6.8714000000')),
#  (11500,
#   'US-2015-108966',
#   datetime.date(2015, 10, 11),
#   datetime.date(2015, 10, 18),
#   'Standard Class',
#   'SO-20335',
#   "Sean O'Donnell",
#   'Consumer',
#   'United States',
#   'Fort Lauderdale',
#   'Florida',
#   '33311',
#   'South',
#   'FUR-TA-10000577',
#   'Bretford CR4500 Series Slim Rectangular Table',
#   'Furniture',
#   'Tables',
#   Decimal('957.5775000000'),
#   Decimal('5.0000000000'),
#   Decimal('0.4500000000'),
#   Decimal('-383.0310000000')),
#  (11501,
#   'US-2015-108966',
#   datetime.date(2015, 10, 11),
#   datetime.date(2015, 10, 18),
#   'Standard Class',
#   'SO-20335',
#   "Sean O'Donnell",
#   'Consumer',
#   'United States',
#   'Fort Lauderdale',
#   'Florida',
#   '33311',
#   'South',
#   'OFF-ST-10000760',
#   "Eldon Fold 'N Roll Cart System",
#   'Office Supplies',
#   'Storage',
#   Decimal('22.3680000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('2.5164000000')),
#  (11502,
#   'CA-2014-115812',
#   datetime.date(2014, 6, 9),
#   datetime.date(2014, 6, 14),
#   'Standard Class',
#   'BH-11710',
#   'Brosina Hoffman',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90032',
#   'West',
#   'FUR-FU-10001487',
#   'Eldon Expressions Wood and Plastic Desk Accessories, Cherry Wood',
#   'Furniture',
#   'Furnishings',
#   Decimal('48.8600000000'),
#   Decimal('7.0000000000'),
#   Decimal('0E-10'),
#   Decimal('14.1694000000')),
#  (11503,
#   'CA-2014-115812',
#   datetime.date(2014, 6, 9),
#   datetime.date(2014, 6, 14),
#   'Standard Class',
#   'BH-11710',
#   'Brosina Hoffman',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90032',
#   'West',
#   'OFF-AR-10002833',
#   'Newell 322',
#   'Office Supplies',
#   'Art',
#   Decimal('7.2800000000'),
#   Decimal('4.0000000000'),
#   Decimal('0E-10'),
#   Decimal('1.9656000000')),
#  (11504,
#   'CA-2014-115812',
#   datetime.date(2014, 6, 9),
#   datetime.date(2014, 6, 14),
#   'Standard Class',
#   'BH-11710',
#   'Brosina Hoffman',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90032',
#   'West',
#   'TEC-PH-10002275',
#   'Mitel 5320 IP Phone VoIP phone',
#   'Technology',
#   'Phones',
#   Decimal('907.1520000000'),
#   Decimal('6.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('90.7152000000')),
#  (11505,
#   'CA-2014-115812',
#   datetime.date(2014, 6, 9),
#   datetime.date(2014, 6, 14),
#   'Standard Class',
#   'BH-11710',
#   'Brosina Hoffman',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90032',
#   'West',
#   'OFF-BI-10003910',
#   'DXL Angle-View Binders with Locking Rings by Samsill',
#   'Office Supplies',
#   'Binders',
#   Decimal('18.5040000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('5.7825000000')),
#  (11506,
#   'CA-2014-115812',
#   datetime.date(2014, 6, 9),
#   datetime.date(2014, 6, 14),
#   'Standard Class',
#   'BH-11710',
#   'Brosina Hoffman',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90032',
#   'West',
#   'OFF-AP-10002892',
#   'Belkin F5C206VTEL 6 Outlet Surge',
#   'Office Supplies',
#   'Appliances',
#   Decimal('114.9000000000'),
#   Decimal('5.0000000000'),
#   Decimal('0E-10'),
#   Decimal('34.4700000000')),
#  (11507,
#   'CA-2014-115812',
#   datetime.date(2014, 6, 9),
#   datetime.date(2014, 6, 14),
#   'Standard Class',
#   'BH-11710',
#   'Brosina Hoffman',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90032',
#   'West',
#   'FUR-TA-10001539',
#   'Chromcraft Rectangular Conference Tables',
#   'Furniture',
#   'Tables',
#   Decimal('1706.1840000000'),
#   Decimal('9.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('85.3092000000')),
#  (11508,
#   'CA-2014-115812',
#   datetime.date(2014, 6, 9),
#   datetime.date(2014, 6, 14),
#   'Standard Class',
#   'BH-11710',
#   'Brosina Hoffman',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90032',
#   'West',
#   'TEC-PH-10002033',
#   'Konftel 250 Conference\xa0phone\xa0- Charcoal black',
#   'Technology',
#   'Phones',
#   Decimal('911.4240000000'),
#   Decimal('4.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('68.3568000000')),
#  (11509,
#   'CA-2017-114412',
#   datetime.date(2017, 4, 15),
#   datetime.date(2017, 4, 20),
#   'Standard Class',
#   'AA-10480',
#   'Andrew Allen',
#   'Consumer',
#   'United States',
#   'Concord',
#   'North Carolina',
#   '28027',
#   'South',
#   'OFF-PA-10002365',
#   'Xerox 1967',
#   'Office Supplies',
#   'Paper',
#   Decimal('15.5520000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('5.4432000000')),
#  (11510,
#   'CA-2016-161389',
#   datetime.date(2016, 12, 5),
#   datetime.date(2016, 12, 10),
#   'Standard Class',
#   'IM-15070',
#   'Irene Maddox',
#   'Consumer',
#   'United States',
#   'Seattle',
#   'Washington',
#   '98103',
#   'West',
#   'OFF-BI-10003656',
#   'Fellowes PB200 Plastic Comb Binding Machine',
#   'Office Supplies',
#   'Binders',
#   Decimal('407.9760000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('132.5922000000')),
#  (11511,
#   'US-2015-118983',
#   datetime.date(2015, 11, 22),
#   datetime.date(2015, 11, 26),
#   'Standard Class',
#   'HP-14815',
#   'Harold Pawlan',
#   'Home Office',
#   'United States',
#   'Fort Worth',
#   'Texas',
#   '76106',
#   'Central',
#   'OFF-AP-10002311',
#   'Holmes Replacement Filter for HEPA Air Cleaner, Very Large Room, HEPA Filter',
#   'Office Supplies',
#   'Appliances',
#   Decimal('68.8100000000'),
#   Decimal('5.0000000000'),
#   Decimal('0.8000000000'),
#   Decimal('-123.8580000000')),
#  (11512,
#   'US-2015-118983',
#   datetime.date(2015, 11, 22),
#   datetime.date(2015, 11, 26),
#   'Standard Class',
#   'HP-14815',
#   'Harold Pawlan',
#   'Home Office',
#   'United States',
#   'Fort Worth',
#   'Texas',
#   '76106',
#   'Central',
#   'OFF-BI-10000756',
#   'Storex DuraTech Recycled Plastic Frosted Binders',
#   'Office Supplies',
#   'Binders',
#   Decimal('2.5440000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.8000000000'),
#   Decimal('-3.8160000000')),
#  (11513,
#   'CA-2014-105893',
#   datetime.date(2014, 11, 11),
#   datetime.date(2014, 11, 18),
#   'Standard Class',
#   'PK-19075',
#   'Pete Kriz',
#   'Consumer',
#   'United States',
#   'Madison',
#   'Wisconsin',
#   '53711',
#   'Central',
#   'OFF-ST-10004186',
#   'Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x 36"W x 18 1/2"D',
#   'Office Supplies',
#   'Storage',
#   Decimal('665.8800000000'),
#   Decimal('6.0000000000'),
#   Decimal('0E-10'),
#   Decimal('13.3176000000')),
#  (11514,
#   'CA-2014-167164',
#   datetime.date(2014, 5, 13),
#   datetime.date(2014, 5, 15),
#   'Second Class',
#   'AG-10270',
#   'Alejandro Grove',
#   'Consumer',
#   'United States',
#   'West Jordan',
#   'Utah',
#   '84084',
#   'West',
#   'OFF-ST-10000107',
#   'Fellowes Super Stor/Drawer',
#   'Office Supplies',
#   'Storage',
#   Decimal('55.5000000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('9.9900000000')),
#  (11515,
#   'CA-2014-143336',
#   datetime.date(2014, 8, 27),
#   datetime.date(2014, 9, 1),
#   'Second Class',
#   'ZD-21925',
#   'Zuschuss Donatelli',
#   'Consumer',
#   'United States',
#   'San Francisco',
#   'California',
#   '94109',
#   'West',
#   'OFF-AR-10003056',
#   'Newell 341',
#   'Office Supplies',
#   'Art',
#   Decimal('8.5600000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('2.4824000000')),
#  (11516,
#   'CA-2014-143336',
#   datetime.date(2014, 8, 27),
#   datetime.date(2014, 9, 1),
#   'Second Class',
#   'ZD-21925',
#   'Zuschuss Donatelli',
#   'Consumer',
#   'United States',
#   'San Francisco',
#   'California',
#   '94109',
#   'West',
#   'TEC-PH-10001949',
#   'Cisco SPA 501G IP Phone',
#   'Technology',
#   'Phones',
#   Decimal('213.4800000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('16.0110000000')),
#  (11517,
#   'CA-2014-143336',
#   datetime.date(2014, 8, 27),
#   datetime.date(2014, 9, 1),
#   'Second Class',
#   'ZD-21925',
#   'Zuschuss Donatelli',
#   'Consumer',
#   'United States',
#   'San Francisco',
#   'California',
#   '94109',
#   'West',
#   'OFF-BI-10002215',
#   'Wilson Jones Hanging View Binder, White, 1"',
#   'Office Supplies',
#   'Binders',
#   Decimal('22.7200000000'),
#   Decimal('4.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('7.3840000000')),
#  (11518,
#   'CA-2016-137330',
#   datetime.date(2016, 12, 9),
#   datetime.date(2016, 12, 13),
#   'Standard Class',
#   'KB-16585',
#   'Ken Black',
#   'Corporate',
#   'United States',
#   'Fremont',
#   'Nebraska',
#   '68025',
#   'Central',
#   'OFF-AR-10000246',
#   'Newell 318',
#   'Office Supplies',
#   'Art',
#   Decimal('19.4600000000'),
#   Decimal('7.0000000000'),
#   Decimal('0E-10'),
#   Decimal('5.0596000000')),
#  (11519,
#   'CA-2016-137330',
#   datetime.date(2016, 12, 9),
#   datetime.date(2016, 12, 13),
#   'Standard Class',
#   'KB-16585',
#   'Ken Black',
#   'Corporate',
#   'United States',
#   'Fremont',
#   'Nebraska',
#   '68025',
#   'Central',
#   'OFF-AP-10001492',
#   "Acco Six-Outlet Power Strip, 4' Cord Length",
#   'Office Supplies',
#   'Appliances',
#   Decimal('60.3400000000'),
#   Decimal('7.0000000000'),
#   Decimal('0E-10'),
#   Decimal('15.6884000000')),
#  (11520,
#   'US-2017-156909',
#   datetime.date(2017, 7, 16),
#   datetime.date(2017, 7, 18),
#   'Second Class',
#   'SF-20065',
#   'Sandra Flanagan',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19140',
#   'East',
#   'FUR-CH-10002774',
#   'Global Deluxe Stacking Chair, Gray',
#   'Furniture',
#   'Chairs',
#   Decimal('71.3720000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.3000000000'),
#   Decimal('-1.0196000000')),
#  (11521,
#   'CA-2015-106320',
#   datetime.date(2015, 9, 25),
#   datetime.date(2015, 9, 30),
#   'Standard Class',
#   'EB-13870',
#   'Emily Burns',
#   'Consumer',
#   'United States',
#   'Orem',
#   'Utah',
#   '84057',
#   'West',
#   'FUR-TA-10000577',
#   'Bretford CR4500 Series Slim Rectangular Table',
#   'Furniture',
#   'Tables',
#   Decimal('1044.6300000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('240.2649000000')),
#  (11522,
#   'CA-2016-121755',
#   datetime.date(2016, 1, 16),
#   datetime.date(2016, 1, 20),
#   'Second Class',
#   'EH-13945',
#   'Eric Hoffmann',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90049',
#   'West',
#   'OFF-BI-10001634',
#   'Wilson Jones Active Use Binders',
#   'Office Supplies',
#   'Binders',
#   Decimal('11.6480000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('4.2224000000')),
#  (11523,
#   'CA-2016-121755',
#   datetime.date(2016, 1, 16),
#   datetime.date(2016, 1, 20),
#   'Second Class',
#   'EH-13945',
#   'Eric Hoffmann',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90049',
#   'West',
#   'TEC-AC-10003027',
#   'Imation\xa08GB Mini TravelDrive USB 2.0\xa0Flash Drive',
#   'Technology',
#   'Accessories',
#   Decimal('90.5700000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('11.7741000000')),
#  (11524,
#   'US-2015-150630',
#   datetime.date(2015, 9, 17),
#   datetime.date(2015, 9, 21),
#   'Standard Class',
#   'TB-21520',
#   'Tracy Blumstein',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19140',
#   'East',
#   'FUR-BO-10004834',
#   'Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish',
#   'Furniture',
#   'Bookcases',
#   Decimal('3083.4300000000'),
#   Decimal('7.0000000000'),
#   Decimal('0.5000000000'),
#   Decimal('-1665.0522000000')),
#  (11525,
#   'US-2015-150630',
#   datetime.date(2015, 9, 17),
#   datetime.date(2015, 9, 21),
#   'Standard Class',
#   'TB-21520',
#   'Tracy Blumstein',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19140',
#   'East',
#   'OFF-BI-10000474',
#   'Avery Recycled Flexi-View Covers for Binding Systems',
#   'Office Supplies',
#   'Binders',
#   Decimal('9.6180000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.7000000000'),
#   Decimal('-7.0532000000')),
#  (11585,
#   'CA-2016-159695',
#   datetime.date(2016, 4, 5),
#   datetime.date(2016, 4, 10),
#   'Second Class',
#   'GM-14455',
#   'Gary Mitchum',
#   'Home Office',
#   'United States',
#   'Houston',
#   'Texas',
#   '77095',
#   'Central',
#   'OFF-ST-10003442',
#   'Eldon Portable Mobile Manager',
#   'Office Supplies',
#   'Storage',
#   Decimal('158.3680000000'),
#   Decimal('7.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('13.8572000000')),
#  (11526,
#   'US-2015-150630',
#   datetime.date(2015, 9, 17),
#   datetime.date(2015, 9, 21),
#   'Standard Class',
#   'TB-21520',
#   'Tracy Blumstein',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19140',
#   'East',
#   'FUR-FU-10004848',
#   'Howard Miller 13-3/4" Diameter Brushed Chrome Round Wall Clock',
#   'Furniture',
#   'Furnishings',
#   Decimal('124.2000000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('15.5250000000')),
#  (11527,
#   'US-2015-150630',
#   datetime.date(2015, 9, 17),
#   datetime.date(2015, 9, 21),
#   'Standard Class',
#   'TB-21520',
#   'Tracy Blumstein',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19140',
#   'East',
#   'OFF-EN-10001509',
#   'Poly String Tie Envelopes',
#   'Office Supplies',
#   'Envelopes',
#   Decimal('3.2640000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('1.1016000000')),
#  (11528,
#   'US-2015-150630',
#   datetime.date(2015, 9, 17),
#   datetime.date(2015, 9, 21),
#   'Standard Class',
#   'TB-21520',
#   'Tracy Blumstein',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19140',
#   'East',
#   'OFF-AR-10004042',
#   'BOSTON Model 1800 Electric Pencil Sharpeners, Putty/Woodgrain',
#   'Office Supplies',
#   'Art',
#   Decimal('86.3040000000'),
#   Decimal('6.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('9.7092000000')),
#  (11529,
#   'US-2015-150630',
#   datetime.date(2015, 9, 17),
#   datetime.date(2015, 9, 21),
#   'Standard Class',
#   'TB-21520',
#   'Tracy Blumstein',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19140',
#   'East',
#   'OFF-BI-10001525',
#   'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Executive Red',
#   'Office Supplies',
#   'Binders',
#   Decimal('6.8580000000'),
#   Decimal('6.0000000000'),
#   Decimal('0.7000000000'),
#   Decimal('-5.7150000000')),
#  (11530,
#   'US-2015-150630',
#   datetime.date(2015, 9, 17),
#   datetime.date(2015, 9, 21),
#   'Standard Class',
#   'TB-21520',
#   'Tracy Blumstein',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19140',
#   'East',
#   'OFF-AR-10001683',
#   'Lumber Crayons',
#   'Office Supplies',
#   'Art',
#   Decimal('15.7600000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('3.5460000000')),
#  (11531,
#   'CA-2017-107727',
#   datetime.date(2017, 10, 19),
#   datetime.date(2017, 10, 23),
#   'Second Class',
#   'MA-17560',
#   'Matt Abelman',
#   'Home Office',
#   'United States',
#   'Houston',
#   'Texas',
#   '77095',
#   'Central',
#   'OFF-PA-10000249',
#   'Easy-staple paper',
#   'Office Supplies',
#   'Paper',
#   Decimal('29.4720000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('9.9468000000')),
#  (11532,
#   'CA-2016-117590',
#   datetime.date(2016, 12, 8),
#   datetime.date(2016, 12, 10),
#   'First Class',
#   'GH-14485',
#   'Gene Hale',
#   'Corporate',
#   'United States',
#   'Richardson',
#   'Texas',
#   '75080',
#   'Central',
#   'TEC-PH-10004977',
#   'GE 30524EE4',
#   'Technology',
#   'Phones',
#   Decimal('1097.5440000000'),
#   Decimal('7.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('123.4737000000')),
#  (11533,
#   'CA-2016-117590',
#   datetime.date(2016, 12, 8),
#   datetime.date(2016, 12, 10),
#   'First Class',
#   'GH-14485',
#   'Gene Hale',
#   'Corporate',
#   'United States',
#   'Richardson',
#   'Texas',
#   '75080',
#   'Central',
#   'FUR-FU-10003664',
#   "Electrix Architect's Clamp-On Swing Arm Lamp, Black",
#   'Furniture',
#   'Furnishings',
#   Decimal('190.9200000000'),
#   Decimal('5.0000000000'),
#   Decimal('0.6000000000'),
#   Decimal('-147.9630000000')),
#  (11534,
#   'CA-2015-117415',
#   datetime.date(2015, 12, 27),
#   datetime.date(2015, 12, 31),
#   'Standard Class',
#   'SN-20710',
#   'Steve Nguyen',
#   'Home Office',
#   'United States',
#   'Houston',
#   'Texas',
#   '77041',
#   'Central',
#   'OFF-EN-10002986',
#   '#10-4 1/8" x 9 1/2" Premium Diagonal Seam Envelopes',
#   'Office Supplies',
#   'Envelopes',
#   Decimal('113.3280000000'),
#   Decimal('9.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('35.4150000000')),
#  (11535,
#   'CA-2015-117415',
#   datetime.date(2015, 12, 27),
#   datetime.date(2015, 12, 31),
#   'Standard Class',
#   'SN-20710',
#   'Steve Nguyen',
#   'Home Office',
#   'United States',
#   'Houston',
#   'Texas',
#   '77041',
#   'Central',
#   'FUR-BO-10002545',
#   'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors',
#   'Furniture',
#   'Bookcases',
#   Decimal('532.3992000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.3200000000'),
#   Decimal('-46.9764000000')),
#  (11536,
#   'CA-2015-117415',
#   datetime.date(2015, 12, 27),
#   datetime.date(2015, 12, 31),
#   'Standard Class',
#   'SN-20710',
#   'Steve Nguyen',
#   'Home Office',
#   'United States',
#   'Houston',
#   'Texas',
#   '77041',
#   'Central',
#   'FUR-CH-10004218',
#   "Global Fabric Manager's Chair, Dark Gray",
#   'Furniture',
#   'Chairs',
#   Decimal('212.0580000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.3000000000'),
#   Decimal('-15.1470000000')),
#  (11537,
#   'CA-2015-117415',
#   datetime.date(2015, 12, 27),
#   datetime.date(2015, 12, 31),
#   'Standard Class',
#   'SN-20710',
#   'Steve Nguyen',
#   'Home Office',
#   'United States',
#   'Houston',
#   'Texas',
#   '77041',
#   'Central',
#   'TEC-PH-10000486',
#   'Plantronics HL10 Handset Lifter',
#   'Technology',
#   'Phones',
#   Decimal('371.1680000000'),
#   Decimal('4.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('41.7564000000')),
#  (11538,
#   'CA-2017-120999',
#   datetime.date(2017, 9, 10),
#   datetime.date(2017, 9, 15),
#   'Standard Class',
#   'LC-16930',
#   'Linda Cazamias',
#   'Corporate',
#   'United States',
#   'Naperville',
#   'Illinois',
#   '60540',
#   'Central',
#   'TEC-PH-10004093',
#   'Panasonic Kx-TS550',
#   'Technology',
#   'Phones',
#   Decimal('147.1680000000'),
#   Decimal('4.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('16.5564000000')),
#  (11539,
#   'CA-2016-101343',
#   datetime.date(2016, 7, 17),
#   datetime.date(2016, 7, 22),
#   'Standard Class',
#   'RA-19885',
#   'Ruben Ausman',
#   'Corporate',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90049',
#   'West',
#   'OFF-ST-10003479',
#   'Eldon Base for stackable storage shelf, platinum',
#   'Office Supplies',
#   'Storage',
#   Decimal('77.8800000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('3.8940000000')),
#  (11540,
#   'CA-2017-139619',
#   datetime.date(2017, 9, 19),
#   datetime.date(2017, 9, 23),
#   'Standard Class',
#   'ES-14080',
#   'Erin Smith',
#   'Corporate',
#   'United States',
#   'Melbourne',
#   'Florida',
#   '32935',
#   'South',
#   'OFF-ST-10003282',
#   'Advantus 10-Drawer Portable Organizer, Chrome Metal Frame, Smoke Drawers',
#   'Office Supplies',
#   'Storage',
#   Decimal('95.6160000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('9.5616000000')),
#  (11541,
#   'CA-2016-118255',
#   datetime.date(2016, 3, 11),
#   datetime.date(2016, 3, 13),
#   'First Class',
#   'ON-18715',
#   'Odella Nelson',
#   'Corporate',
#   'United States',
#   'Eagan',
#   'Minnesota',
#   '55122',
#   'Central',
#   'TEC-AC-10000171',
#   'Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc, 25/Pack',
#   'Technology',
#   'Accessories',
#   Decimal('45.9800000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('19.7714000000')),
#  (11542,
#   'CA-2016-118255',
#   datetime.date(2016, 3, 11),
#   datetime.date(2016, 3, 13),
#   'First Class',
#   'ON-18715',
#   'Odella Nelson',
#   'Corporate',
#   'United States',
#   'Eagan',
#   'Minnesota',
#   '55122',
#   'Central',
#   'OFF-BI-10003291',
#   'Wilson Jones Leather-Like Binders with DublLock Round Rings',
#   'Office Supplies',
#   'Binders',
#   Decimal('17.4600000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('8.2062000000')),
#  (11543,
#   'CA-2014-146703',
#   datetime.date(2014, 10, 20),
#   datetime.date(2014, 10, 25),
#   'Second Class',
#   'PO-18865',
#   "Patrick O'Donnell",
#   'Consumer',
#   'United States',
#   'Westland',
#   'Michigan',
#   '48185',
#   'Central',
#   'OFF-ST-10001713',
#   'Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5-1/4d x 20-1/2h, Black',
#   'Office Supplies',
#   'Storage',
#   Decimal('211.9600000000'),
#   Decimal('4.0000000000'),
#   Decimal('0E-10'),
#   Decimal('8.4784000000')),
#  (11544,
#   'CA-2016-169194',
#   datetime.date(2016, 6, 20),
#   datetime.date(2016, 6, 25),
#   'Standard Class',
#   'LH-16900',
#   'Lena Hernandez',
#   'Consumer',
#   'United States',
#   'Dover',
#   'Delaware',
#   '19901',
#   'East',
#   'TEC-AC-10002167',
#   'Imation\xa08gb Micro Traveldrive Usb 2.0\xa0Flash Drive',
#   'Technology',
#   'Accessories',
#   Decimal('45.0000000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('4.9500000000')),
#  (11545,
#   'CA-2016-169194',
#   datetime.date(2016, 6, 20),
#   datetime.date(2016, 6, 25),
#   'Standard Class',
#   'LH-16900',
#   'Lena Hernandez',
#   'Consumer',
#   'United States',
#   'Dover',
#   'Delaware',
#   '19901',
#   'East',
#   'TEC-PH-10003988',
#   'LF Elite 3D Dazzle Designer Hard Case Cover, Lf Stylus Pen and Wiper For Apple Iphone 5c Mini Lite',
#   'Technology',
#   'Phones',
#   Decimal('21.8000000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('6.1040000000')),
#  (11546,
#   'CA-2015-115742',
#   datetime.date(2015, 4, 18),
#   datetime.date(2015, 4, 22),
#   'Standard Class',
#   'DP-13000',
#   'Darren Powers',
#   'Consumer',
#   'United States',
#   'New Albany',
#   'Indiana',
#   '47150',
#   'Central',
#   'OFF-BI-10004410',
#   'C-Line Peel & Stick Add-On Filing Pockets, 8-3/4 x 5-1/8, 10/Pack',
#   'Office Supplies',
#   'Binders',
#   Decimal('38.2200000000'),
#   Decimal('6.0000000000'),
#   Decimal('0E-10'),
#   Decimal('17.9634000000')),
#  (11547,
#   'CA-2015-115742',
#   datetime.date(2015, 4, 18),
#   datetime.date(2015, 4, 22),
#   'Standard Class',
#   'DP-13000',
#   'Darren Powers',
#   'Consumer',
#   'United States',
#   'New Albany',
#   'Indiana',
#   '47150',
#   'Central',
#   'OFF-LA-10002762',
#   'Avery 485',
#   'Office Supplies',
#   'Labels',
#   Decimal('75.1800000000'),
#   Decimal('6.0000000000'),
#   Decimal('0E-10'),
#   Decimal('35.3346000000')),
#  (11548,
#   'CA-2015-115742',
#   datetime.date(2015, 4, 18),
#   datetime.date(2015, 4, 22),
#   'Standard Class',
#   'DP-13000',
#   'Darren Powers',
#   'Consumer',
#   'United States',
#   'New Albany',
#   'Indiana',
#   '47150',
#   'Central',
#   'FUR-FU-10001706',
#   'Longer-Life Soft White Bulbs',
#   'Furniture',
#   'Furnishings',
#   Decimal('6.1600000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('2.9568000000')),
#  (11549,
#   'CA-2015-115742',
#   datetime.date(2015, 4, 18),
#   datetime.date(2015, 4, 22),
#   'Standard Class',
#   'DP-13000',
#   'Darren Powers',
#   'Consumer',
#   'United States',
#   'New Albany',
#   'Indiana',
#   '47150',
#   'Central',
#   'FUR-CH-10003061',
#   'Global Leather Task Chair, Black',
#   'Furniture',
#   'Chairs',
#   Decimal('89.9900000000'),
#   Decimal('1.0000000000'),
#   Decimal('0E-10'),
#   Decimal('17.0981000000')),
#  (11550,
#   'CA-2016-105816',
#   datetime.date(2016, 12, 11),
#   datetime.date(2016, 12, 17),
#   'Standard Class',
#   'JM-15265',
#   'Janet Molinari',
#   'Corporate',
#   'United States',
#   'New York City',
#   'New York',
#   '10024',
#   'East',
#   'OFF-FA-10000304',
#   'Advantus Push Pins',
#   'Office Supplies',
#   'Fasteners',
#   Decimal('15.2600000000'),
#   Decimal('7.0000000000'),
#   Decimal('0E-10'),
#   Decimal('6.2566000000')),
#  (11551,
#   'CA-2016-105816',
#   datetime.date(2016, 12, 11),
#   datetime.date(2016, 12, 17),
#   'Standard Class',
#   'JM-15265',
#   'Janet Molinari',
#   'Corporate',
#   'United States',
#   'New York City',
#   'New York',
#   '10024',
#   'East',
#   'TEC-PH-10002447',
#   'AT&T CL83451 4-Handset Telephone',
#   'Technology',
#   'Phones',
#   Decimal('1029.9500000000'),
#   Decimal('5.0000000000'),
#   Decimal('0E-10'),
#   Decimal('298.6855000000')),
#  (11552,
#   'CA-2016-111682',
#   datetime.date(2016, 6, 17),
#   datetime.date(2016, 6, 18),
#   'First Class',
#   'TB-21055',
#   'Ted Butterfield',
#   'Consumer',
#   'United States',
#   'Troy',
#   'New York',
#   '12180',
#   'East',
#   'OFF-ST-10000604',
#   'Home/Office Personal File Carts',
#   'Office Supplies',
#   'Storage',
#   Decimal('208.5600000000'),
#   Decimal('6.0000000000'),
#   Decimal('0E-10'),
#   Decimal('52.1400000000')),
#  (11553,
#   'CA-2016-111682',
#   datetime.date(2016, 6, 17),
#   datetime.date(2016, 6, 18),
#   'First Class',
#   'TB-21055',
#   'Ted Butterfield',
#   'Consumer',
#   'United States',
#   'Troy',
#   'New York',
#   '12180',
#   'East',
#   'OFF-PA-10001569',
#   'Xerox 232',
#   'Office Supplies',
#   'Paper',
#   Decimal('32.4000000000'),
#   Decimal('5.0000000000'),
#   Decimal('0E-10'),
#   Decimal('15.5520000000')),
#  (11554,
#   'CA-2016-111682',
#   datetime.date(2016, 6, 17),
#   datetime.date(2016, 6, 18),
#   'First Class',
#   'TB-21055',
#   'Ted Butterfield',
#   'Consumer',
#   'United States',
#   'Troy',
#   'New York',
#   '12180',
#   'East',
#   'FUR-CH-10003968',
#   'Novimex Turbo Task Chair',
#   'Furniture',
#   'Chairs',
#   Decimal('319.4100000000'),
#   Decimal('5.0000000000'),
#   Decimal('0.1000000000'),
#   Decimal('7.0980000000')),
#  (11555,
#   'CA-2016-111682',
#   datetime.date(2016, 6, 17),
#   datetime.date(2016, 6, 18),
#   'First Class',
#   'TB-21055',
#   'Ted Butterfield',
#   'Consumer',
#   'United States',
#   'Troy',
#   'New York',
#   '12180',
#   'East',
#   'OFF-PA-10000587',
#   'Array Parchment Paper, Assorted Colors',
#   'Office Supplies',
#   'Paper',
#   Decimal('14.5600000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('6.9888000000')),
#  (11556,
#   'CA-2016-111682',
#   datetime.date(2016, 6, 17),
#   datetime.date(2016, 6, 18),
#   'First Class',
#   'TB-21055',
#   'Ted Butterfield',
#   'Consumer',
#   'United States',
#   'Troy',
#   'New York',
#   '12180',
#   'East',
#   'TEC-AC-10002167',
#   'Imation\xa08gb Micro Traveldrive Usb 2.0\xa0Flash Drive',
#   'Technology',
#   'Accessories',
#   Decimal('30.0000000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('3.3000000000')),
#  (11557,
#   'CA-2016-111682',
#   datetime.date(2016, 6, 17),
#   datetime.date(2016, 6, 18),
#   'First Class',
#   'TB-21055',
#   'Ted Butterfield',
#   'Consumer',
#   'United States',
#   'Troy',
#   'New York',
#   '12180',
#   'East',
#   'OFF-BI-10001460',
#   'Plastic Binding Combs',
#   'Office Supplies',
#   'Binders',
#   Decimal('48.4800000000'),
#   Decimal('4.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('16.3620000000')),
#  (11558,
#   'CA-2016-111682',
#   datetime.date(2016, 6, 17),
#   datetime.date(2016, 6, 18),
#   'First Class',
#   'TB-21055',
#   'Ted Butterfield',
#   'Consumer',
#   'United States',
#   'Troy',
#   'New York',
#   '12180',
#   'East',
#   'OFF-AR-10001868',
#   'Prang Dustless Chalk Sticks',
#   'Office Supplies',
#   'Art',
#   Decimal('1.6800000000'),
#   Decimal('1.0000000000'),
#   Decimal('0E-10'),
#   Decimal('0.8400000000')),
#  (11559,
#   'CA-2015-135545',
#   datetime.date(2015, 11, 24),
#   datetime.date(2015, 11, 30),
#   'Standard Class',
#   'KM-16720',
#   'Kunst Miller',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90004',
#   'West',
#   'TEC-AC-10004633',
#   'Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc, 3/Pack',
#   'Technology',
#   'Accessories',
#   Decimal('13.9800000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('6.1512000000')),
#  (11560,
#   'CA-2015-135545',
#   datetime.date(2015, 11, 24),
#   datetime.date(2015, 11, 30),
#   'Standard Class',
#   'KM-16720',
#   'Kunst Miller',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90004',
#   'West',
#   'OFF-BI-10001078',
#   'Acco PRESSTEX Data Binder with Storage Hooks, Dark Blue, 14 7/8" X 11"',
#   'Office Supplies',
#   'Binders',
#   Decimal('25.8240000000'),
#   Decimal('6.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('9.3612000000')),
#  (11561,
#   'CA-2015-135545',
#   datetime.date(2015, 11, 24),
#   datetime.date(2015, 11, 30),
#   'Standard Class',
#   'KM-16720',
#   'Kunst Miller',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90004',
#   'West',
#   'OFF-PA-10003892',
#   'Xerox 1943',
#   'Office Supplies',
#   'Paper',
#   Decimal('146.7300000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('68.9631000000')),
#  (11562,
#   'CA-2015-135545',
#   datetime.date(2015, 11, 24),
#   datetime.date(2015, 11, 30),
#   'Standard Class',
#   'KM-16720',
#   'Kunst Miller',
#   'Consumer',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90004',
#   'West',
#   'FUR-FU-10000397',
#   'Luxo Economy Swing Arm Lamp',
#   'Furniture',
#   'Furnishings',
#   Decimal('79.7600000000'),
#   Decimal('4.0000000000'),
#   Decimal('0E-10'),
#   Decimal('22.3328000000')),
#  (11563,
#   'US-2015-164175',
#   datetime.date(2015, 4, 30),
#   datetime.date(2015, 5, 5),
#   'Standard Class',
#   'PS-18970',
#   'Paul Stevenson',
#   'Home Office',
#   'United States',
#   'Chicago',
#   'Illinois',
#   '60610',
#   'Central',
#   'FUR-CH-10001146',
#   "Global Value Mid-Back Manager's Chair, Gray",
#   'Furniture',
#   'Chairs',
#   Decimal('213.1150000000'),
#   Decimal('5.0000000000'),
#   Decimal('0.3000000000'),
#   Decimal('-15.2225000000')),
#  (11564,
#   'CA-2014-106376',
#   datetime.date(2014, 12, 5),
#   datetime.date(2014, 12, 10),
#   'Standard Class',
#   'BS-11590',
#   'Brendan Sweed',
#   'Corporate',
#   'United States',
#   'Gilbert',
#   'Arizona',
#   '85234',
#   'West',
#   'OFF-AR-10002671',
#   'Hunt BOSTON Model 1606 High-Volume Electric Pencil Sharpener, Beige',
#   'Office Supplies',
#   'Art',
#   Decimal('1113.0240000000'),
#   Decimal('8.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('111.3024000000')),
#  (11565,
#   'CA-2014-106376',
#   datetime.date(2014, 12, 5),
#   datetime.date(2014, 12, 10),
#   'Standard Class',
#   'BS-11590',
#   'Brendan Sweed',
#   'Corporate',
#   'United States',
#   'Gilbert',
#   'Arizona',
#   '85234',
#   'West',
#   'TEC-PH-10002726',
#   'netTALK DUO VoIP Telephone Service',
#   'Technology',
#   'Phones',
#   Decimal('167.9680000000'),
#   Decimal('4.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('62.9880000000')),
#  (11566,
#   'CA-2016-119823',
#   datetime.date(2016, 6, 4),
#   datetime.date(2016, 6, 6),
#   'First Class',
#   'KD-16270',
#   'Karen Daniels',
#   'Consumer',
#   'United States',
#   'Springfield',
#   'Virginia',
#   '22153',
#   'South',
#   'OFF-PA-10000482',
#   'Snap-A-Way Black Print Carbonless Ruled Speed Letter, Triplicate',
#   'Office Supplies',
#   'Paper',
#   Decimal('75.8800000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('35.6636000000')),
#  (11567,
#   'CA-2016-106075',
#   datetime.date(2016, 9, 18),
#   datetime.date(2016, 9, 23),
#   'Standard Class',
#   'HM-14980',
#   'Henry MacAllister',
#   'Consumer',
#   'United States',
#   'New York City',
#   'New York',
#   '10009',
#   'East',
#   'OFF-BI-10004654',
#   'Avery Binding System Hidden Tab Executive Style Index Sets',
#   'Office Supplies',
#   'Binders',
#   Decimal('4.6160000000'),
#   Decimal('1.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('1.7310000000')),
#  (11568,
#   'CA-2017-114440',
#   datetime.date(2017, 9, 14),
#   datetime.date(2017, 9, 17),
#   'Second Class',
#   'TB-21520',
#   'Tracy Blumstein',
#   'Consumer',
#   'United States',
#   'Jackson',
#   'Michigan',
#   '49201',
#   'Central',
#   'OFF-PA-10004675',
#   'Telephone Message Books with Fax/Mobile Section, 5 1/2" x 3 3/16"',
#   'Office Supplies',
#   'Paper',
#   Decimal('19.0500000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('8.7630000000')),
#  (11569,
#   'US-2015-134026',
#   datetime.date(2015, 4, 26),
#   datetime.date(2015, 5, 2),
#   'Standard Class',
#   'JE-15745',
#   'Joel Eaton',
#   'Consumer',
#   'United States',
#   'Memphis',
#   'Tennessee',
#   '38109',
#   'South',
#   'FUR-CH-10000513',
#   "High-Back Leather Manager's Chair",
#   'Furniture',
#   'Chairs',
#   Decimal('831.9360000000'),
#   Decimal('8.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('-114.3912000000')),
#  (11570,
#   'US-2015-134026',
#   datetime.date(2015, 4, 26),
#   datetime.date(2015, 5, 2),
#   'Standard Class',
#   'JE-15745',
#   'Joel Eaton',
#   'Consumer',
#   'United States',
#   'Memphis',
#   'Tennessee',
#   '38109',
#   'South',
#   'FUR-FU-10003708',
#   'Tenex Traditional Chairmats for Medium Pile Carpet, Standard Lip, 36" x 48"',
#   'Furniture',
#   'Furnishings',
#   Decimal('97.0400000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('1.2130000000')),
#  (11571,
#   'US-2015-134026',
#   datetime.date(2015, 4, 26),
#   datetime.date(2015, 5, 2),
#   'Standard Class',
#   'JE-15745',
#   'Joel Eaton',
#   'Consumer',
#   'United States',
#   'Memphis',
#   'Tennessee',
#   '38109',
#   'South',
#   'OFF-ST-10004123',
#   'Safco Industrial Wire Shelving System',
#   'Office Supplies',
#   'Storage',
#   Decimal('72.7840000000'),
#   Decimal('1.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('-18.1960000000')),
#  (11572,
#   'US-2017-118038',
#   datetime.date(2017, 12, 9),
#   datetime.date(2017, 12, 11),
#   'First Class',
#   'KB-16600',
#   'Ken Brennan',
#   'Corporate',
#   'United States',
#   'Houston',
#   'Texas',
#   '77041',
#   'Central',
#   'OFF-BI-10004182',
#   'Economy Binders',
#   'Office Supplies',
#   'Binders',
#   Decimal('1.2480000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.8000000000'),
#   Decimal('-1.9344000000')),
#  (11573,
#   'US-2017-118038',
#   datetime.date(2017, 12, 9),
#   datetime.date(2017, 12, 11),
#   'First Class',
#   'KB-16600',
#   'Ken Brennan',
#   'Corporate',
#   'United States',
#   'Houston',
#   'Texas',
#   '77041',
#   'Central',
#   'FUR-FU-10000260',
#   '6" Cubicle Wall Clock, Black',
#   'Furniture',
#   'Furnishings',
#   Decimal('9.7080000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.6000000000'),
#   Decimal('-5.8248000000')),
#  (11574,
#   'US-2017-118038',
#   datetime.date(2017, 12, 9),
#   datetime.date(2017, 12, 11),
#   'First Class',
#   'KB-16600',
#   'Ken Brennan',
#   'Corporate',
#   'United States',
#   'Houston',
#   'Texas',
#   '77041',
#   'Central',
#   'OFF-ST-10000615',
#   'SimpliFile Personal File, Black Granite, 15w x 6-15/16d x 11-1/4h',
#   'Office Supplies',
#   'Storage',
#   Decimal('27.2400000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('2.7240000000')),
#  (11575,
#   'US-2014-147606',
#   datetime.date(2014, 11, 26),
#   datetime.date(2014, 12, 1),
#   'Second Class',
#   'JE-15745',
#   'Joel Eaton',
#   'Consumer',
#   'United States',
#   'Houston',
#   'Texas',
#   '77070',
#   'Central',
#   'FUR-FU-10003194',
#   'Eldon Expressions Desk Accessory, Wood Pencil Holder, Oak',
#   'Furniture',
#   'Furnishings',
#   Decimal('19.3000000000'),
#   Decimal('5.0000000000'),
#   Decimal('0.6000000000'),
#   Decimal('-14.4750000000')),
#  (11576,
#   'CA-2016-127208',
#   datetime.date(2016, 6, 12),
#   datetime.date(2016, 6, 15),
#   'First Class',
#   'SC-20770',
#   'Stewart Carmichael',
#   'Corporate',
#   'United States',
#   'Decatur',
#   'Alabama',
#   '35601',
#   'South',
#   'OFF-AP-10002118',
#   '1.7 Cubic Foot Compact "Cube" Office Refrigerators',
#   'Office Supplies',
#   'Appliances',
#   Decimal('208.1600000000'),
#   Decimal('1.0000000000'),
#   Decimal('0E-10'),
#   Decimal('56.2032000000')),
#  (11577,
#   'CA-2016-127208',
#   datetime.date(2016, 6, 12),
#   datetime.date(2016, 6, 15),
#   'First Class',
#   'SC-20770',
#   'Stewart Carmichael',
#   'Corporate',
#   'United States',
#   'Decatur',
#   'Alabama',
#   '35601',
#   'South',
#   'OFF-BI-10002309',
#   'Avery Heavy-Duty EZD  Binder With Locking Rings',
#   'Office Supplies',
#   'Binders',
#   Decimal('16.7400000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('8.0352000000')),
#  (11578,
#   'CA-2014-139451',
#   datetime.date(2014, 10, 12),
#   datetime.date(2014, 10, 16),
#   'Standard Class',
#   'DN-13690',
#   'Duane Noonan',
#   'Consumer',
#   'United States',
#   'San Francisco',
#   'California',
#   '94122',
#   'West',
#   'OFF-AR-10002053',
#   'Premium Writing Pencils, Soft, #2 by Central Association for the Blind',
#   'Office Supplies',
#   'Art',
#   Decimal('14.9000000000'),
#   Decimal('5.0000000000'),
#   Decimal('0E-10'),
#   Decimal('4.1720000000')),
#  (11579,
#   'CA-2014-139451',
#   datetime.date(2014, 10, 12),
#   datetime.date(2014, 10, 16),
#   'Standard Class',
#   'DN-13690',
#   'Duane Noonan',
#   'Consumer',
#   'United States',
#   'San Francisco',
#   'California',
#   '94122',
#   'West',
#   'OFF-ST-10002370',
#   'Sortfiler Multipurpose Personal File Organizer, Black',
#   'Office Supplies',
#   'Storage',
#   Decimal('21.3900000000'),
#   Decimal('1.0000000000'),
#   Decimal('0E-10'),
#   Decimal('6.2031000000')),
#  (11580,
#   'CA-2015-149734',
#   datetime.date(2015, 9, 3),
#   datetime.date(2015, 9, 8),
#   'Standard Class',
#   'JC-16105',
#   'Julie Creighton',
#   'Corporate',
#   'United States',
#   'Durham',
#   'North Carolina',
#   '27707',
#   'South',
#   'OFF-EN-10000927',
#   "Jet-Pak Recycled Peel 'N' Seal Padded Mailers",
#   'Office Supplies',
#   'Envelopes',
#   Decimal('200.9840000000'),
#   Decimal('7.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('62.8075000000')),
#  (11581,
#   'US-2017-119662',
#   datetime.date(2017, 11, 13),
#   datetime.date(2017, 11, 16),
#   'First Class',
#   'CS-12400',
#   'Christopher Schild',
#   'Home Office',
#   'United States',
#   'Chicago',
#   'Illinois',
#   '60623',
#   'Central',
#   'OFF-ST-10003656',
#   'Safco Industrial Wire Shelving',
#   'Office Supplies',
#   'Storage',
#   Decimal('230.3760000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('-48.9549000000')),
#  (11582,
#   'CA-2017-140088',
#   datetime.date(2017, 5, 28),
#   datetime.date(2017, 5, 30),
#   'Second Class',
#   'PO-18865',
#   "Patrick O'Donnell",
#   'Consumer',
#   'United States',
#   'Columbia',
#   'South Carolina',
#   '29203',
#   'South',
#   'FUR-CH-10000863',
#   'Novimex Swivel Fabric Task Chair',
#   'Furniture',
#   'Chairs',
#   Decimal('301.9600000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('33.2156000000')),
#  (11583,
#   'CA-2017-155558',
#   datetime.date(2017, 10, 26),
#   datetime.date(2017, 11, 2),
#   'Standard Class',
#   'PG-18895',
#   'Paul Gonzalez',
#   'Consumer',
#   'United States',
#   'Rochester',
#   'Minnesota',
#   '55901',
#   'Central',
#   'TEC-AC-10001998',
#   'Logitech\xa0LS21 Speaker System - PC Multimedia - 2.1-CH - Wired',
#   'Technology',
#   'Accessories',
#   Decimal('19.9900000000'),
#   Decimal('1.0000000000'),
#   Decimal('0E-10'),
#   Decimal('6.7966000000')),
#  (11584,
#   'CA-2017-155558',
#   datetime.date(2017, 10, 26),
#   datetime.date(2017, 11, 2),
#   'Standard Class',
#   'PG-18895',
#   'Paul Gonzalez',
#   'Consumer',
#   'United States',
#   'Rochester',
#   'Minnesota',
#   '55901',
#   'Central',
#   'OFF-LA-10000134',
#   'Avery 511',
#   'Office Supplies',
#   'Labels',
#   Decimal('6.1600000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('2.9568000000')),
#  (11586,
#   'CA-2016-109806',
#   datetime.date(2016, 9, 17),
#   datetime.date(2016, 9, 22),
#   'Standard Class',
#   'JS-15685',
#   'Jim Sink',
#   'Corporate',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90036',
#   'West',
#   'OFF-AR-10004930',
#   'Turquoise Lead Holder with Pocket Clip',
#   'Office Supplies',
#   'Art',
#   Decimal('20.1000000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('6.6330000000')),
#  (11587,
#   'CA-2016-109806',
#   datetime.date(2016, 9, 17),
#   datetime.date(2016, 9, 22),
#   'Standard Class',
#   'JS-15685',
#   'Jim Sink',
#   'Corporate',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90036',
#   'West',
#   'TEC-PH-10004093',
#   'Panasonic Kx-TS550',
#   'Technology',
#   'Phones',
#   Decimal('73.5840000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('8.2782000000')),
#  (11588,
#   'CA-2016-109806',
#   datetime.date(2016, 9, 17),
#   datetime.date(2016, 9, 22),
#   'Standard Class',
#   'JS-15685',
#   'Jim Sink',
#   'Corporate',
#   'United States',
#   'Los Angeles',
#   'California',
#   '90036',
#   'West',
#   'OFF-PA-10000304',
#   'Xerox 1995',
#   'Office Supplies',
#   'Paper',
#   Decimal('6.4800000000'),
#   Decimal('1.0000000000'),
#   Decimal('0E-10'),
#   Decimal('3.1104000000')),
#  (11589,
#   'CA-2015-149587',
#   datetime.date(2015, 1, 31),
#   datetime.date(2015, 2, 5),
#   'Second Class',
#   'KB-16315',
#   'Karl Braun',
#   'Consumer',
#   'United States',
#   'Minneapolis',
#   'Minnesota',
#   '55407',
#   'Central',
#   'OFF-PA-10003177',
#   'Xerox 1999',
#   'Office Supplies',
#   'Paper',
#   Decimal('12.9600000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('6.2208000000')),
#  (11590,
#   'CA-2015-149587',
#   datetime.date(2015, 1, 31),
#   datetime.date(2015, 2, 5),
#   'Second Class',
#   'KB-16315',
#   'Karl Braun',
#   'Consumer',
#   'United States',
#   'Minneapolis',
#   'Minnesota',
#   '55407',
#   'Central',
#   'FUR-FU-10003799',
#   'Seth Thomas 13 1/2" Wall Clock',
#   'Furniture',
#   'Furnishings',
#   Decimal('53.3400000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('16.5354000000')),
#  (11591,
#   'CA-2015-149587',
#   datetime.date(2015, 1, 31),
#   datetime.date(2015, 2, 5),
#   'Second Class',
#   'KB-16315',
#   'Karl Braun',
#   'Consumer',
#   'United States',
#   'Minneapolis',
#   'Minnesota',
#   '55407',
#   'Central',
#   'OFF-BI-10002852',
#   'Ibico Standard Transparent Covers',
#   'Office Supplies',
#   'Binders',
#   Decimal('32.9600000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('16.1504000000')),
#  (11592,
#   'US-2017-109484',
#   datetime.date(2017, 11, 6),
#   datetime.date(2017, 11, 12),
#   'Standard Class',
#   'RB-19705',
#   'Roger Barcio',
#   'Home Office',
#   'United States',
#   'Portland',
#   'Oregon',
#   '97206',
#   'West',
#   'OFF-BI-10004738',
#   'Flexible Leather- Look Classic Collection Ring Binder',
#   'Office Supplies',
#   'Binders',
#   Decimal('5.6820000000'),
#   Decimal('1.0000000000'),
#   Decimal('0.7000000000'),
#   Decimal('-3.7880000000')),
#  (11593,
#   'CA-2017-161018',
#   datetime.date(2017, 11, 9),
#   datetime.date(2017, 11, 11),
#   'Second Class',
#   'PN-18775',
#   'Parhena Norris',
#   'Home Office',
#   'United States',
#   'New York City',
#   'New York',
#   '10009',
#   'East',
#   'FUR-FU-10000629',
#   '9-3/4 Diameter Round Wall Clock',
#   'Furniture',
#   'Furnishings',
#   Decimal('96.5300000000'),
#   Decimal('7.0000000000'),
#   Decimal('0E-10'),
#   Decimal('40.5426000000')),
#  (11594,
#   'CA-2017-157833',
#   datetime.date(2017, 6, 17),
#   datetime.date(2017, 6, 20),
#   'First Class',
#   'KD-16345',
#   'Katherine Ducich',
#   'Consumer',
#   'United States',
#   'San Francisco',
#   'California',
#   '94122',
#   'West',
#   'OFF-BI-10001721',
#   'Trimflex Flexible Post Binders',
#   'Office Supplies',
#   'Binders',
#   Decimal('51.3120000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('17.9592000000')),
#  (11595,
#   'CA-2016-149223',
#   datetime.date(2016, 9, 6),
#   datetime.date(2016, 9, 11),
#   'Standard Class',
#   'ER-13855',
#   'Elpida Rittenbach',
#   'Corporate',
#   'United States',
#   'Saint Paul',
#   'Minnesota',
#   '55106',
#   'Central',
#   'OFF-AP-10000358',
#   'Fellowes Basic Home/Office Series Surge Protectors',
#   'Office Supplies',
#   'Appliances',
#   Decimal('77.8800000000'),
#   Decimal('6.0000000000'),
#   Decimal('0E-10'),
#   Decimal('22.5852000000')),
#  (11596,
#   'CA-2016-158568',
#   datetime.date(2016, 8, 29),
#   datetime.date(2016, 9, 2),
#   'Standard Class',
#   'RB-19465',
#   'Rick Bensley',
#   'Home Office',
#   'United States',
#   'Chicago',
#   'Illinois',
#   '60610',
#   'Central',
#   'OFF-PA-10003256',
#   'Avery Personal Creations Heavyweight Cards',
#   'Office Supplies',
#   'Paper',
#   Decimal('64.6240000000'),
#   Decimal('7.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('22.6184000000')),
#  (11597,
#   'CA-2016-158568',
#   datetime.date(2016, 8, 29),
#   datetime.date(2016, 9, 2),
#   'Standard Class',
#   'RB-19465',
#   'Rick Bensley',
#   'Home Office',
#   'United States',
#   'Chicago',
#   'Illinois',
#   '60610',
#   'Central',
#   'TEC-AC-10001767',
#   'SanDisk Ultra 64 GB MicroSDHC Class 10 Memory Card',
#   'Technology',
#   'Accessories',
#   Decimal('95.9760000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('-10.7973000000')),
#  (11598,
#   'CA-2016-158568',
#   datetime.date(2016, 8, 29),
#   datetime.date(2016, 9, 2),
#   'Standard Class',
#   'RB-19465',
#   'Rick Bensley',
#   'Home Office',
#   'United States',
#   'Chicago',
#   'Illinois',
#   '60610',
#   'Central',
#   'OFF-BI-10002609',
#   'Avery Hidden Tab Dividers for Binding Systems',
#   'Office Supplies',
#   'Binders',
#   Decimal('1.7880000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.8000000000'),
#   Decimal('-3.0396000000')),
#  (11599,
#   'CA-2016-129903',
#   datetime.date(2016, 12, 1),
#   datetime.date(2016, 12, 4),
#   'Second Class',
#   'GZ-14470',
#   'Gary Zandusky',
#   'Consumer',
#   'United States',
#   'Rochester',
#   'Minnesota',
#   '55901',
#   'Central',
#   'OFF-PA-10004040',
#   'Universal Premium White Copier/Laser Paper (20Lb. and 87 Bright)',
#   'Office Supplies',
#   'Paper',
#   Decimal('23.9200000000'),
#   Decimal('4.0000000000'),
#   Decimal('0E-10'),
#   Decimal('11.7208000000')),
#  (11600,
#   'US-2015-156867',
#   datetime.date(2015, 11, 13),
#   datetime.date(2015, 11, 17),
#   'Standard Class',
#   'LC-16870',
#   'Lena Cacioppo',
#   'Consumer',
#   'United States',
#   'Aurora',
#   'Colorado',
#   '80013',
#   'West',
#   'TEC-AC-10001552',
#   'Logitech K350 2.4Ghz Wireless Keyboard',
#   'Technology',
#   'Accessories',
#   Decimal('238.8960000000'),
#   Decimal('6.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('-26.8758000000')),
#  (11601,
#   'US-2015-156867',
#   datetime.date(2015, 11, 13),
#   datetime.date(2015, 11, 17),
#   'Standard Class',
#   'LC-16870',
#   'Lena Cacioppo',
#   'Consumer',
#   'United States',
#   'Aurora',
#   'Colorado',
#   '80013',
#   'West',
#   'FUR-FU-10004006',
#   'Deflect-o DuraMat Lighweight, Studded, Beveled Mat for Low Pile Carpeting',
#   'Furniture',
#   'Furnishings',
#   Decimal('102.3600000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('-3.8385000000')),
#  (11602,
#   'US-2015-156867',
#   datetime.date(2015, 11, 13),
#   datetime.date(2015, 11, 17),
#   'Standard Class',
#   'LC-16870',
#   'Lena Cacioppo',
#   'Consumer',
#   'United States',
#   'Aurora',
#   'Colorado',
#   '80013',
#   'West',
#   'OFF-BI-10002794',
#   'Avery Trapezoid Ring Binder, 3" Capacity, Black, 1040 sheets',
#   'Office Supplies',
#   'Binders',
#   Decimal('36.8820000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.7000000000'),
#   Decimal('-25.8174000000')),
#  (11603,
#   'CA-2017-119004',
#   datetime.date(2017, 11, 23),
#   datetime.date(2017, 11, 28),
#   'Standard Class',
#   'JM-15250',
#   'Janet Martin',
#   'Consumer',
#   'United States',
#   'Charlotte',
#   'North Carolina',
#   '28205',
#   'South',
#   'TEC-AC-10003499',
#   'Memorex Mini Travel Drive 8 GB USB 2.0 Flash Drive',
#   'Technology',
#   'Accessories',
#   Decimal('74.1120000000'),
#   Decimal('8.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('17.6016000000')),
#  (11604,
#   'CA-2017-119004',
#   datetime.date(2017, 11, 23),
#   datetime.date(2017, 11, 28),
#   'Standard Class',
#   'JM-15250',
#   'Janet Martin',
#   'Consumer',
#   'United States',
#   'Charlotte',
#   'North Carolina',
#   '28205',
#   'South',
#   'TEC-PH-10002844',
#   'Speck Products Candyshell Flip Case',
#   'Technology',
#   'Phones',
#   Decimal('27.9920000000'),
#   Decimal('1.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('2.0994000000')),
#  (11605,
#   'CA-2017-119004',
#   datetime.date(2017, 11, 23),
#   datetime.date(2017, 11, 28),
#   'Standard Class',
#   'JM-15250',
#   'Janet Martin',
#   'Consumer',
#   'United States',
#   'Charlotte',
#   'North Carolina',
#   '28205',
#   'South',
#   'OFF-AR-10000390',
#   'Newell Chalk Holder',
#   'Office Supplies',
#   'Art',
#   Decimal('3.3040000000'),
#   Decimal('1.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('1.0738000000')),
#  (11606,
#   'CA-2015-129476',
#   datetime.date(2015, 10, 15),
#   datetime.date(2015, 10, 20),
#   'Standard Class',
#   'PA-19060',
#   'Pete Armstrong',
#   'Home Office',
#   'United States',
#   'Orland Park',
#   'Illinois',
#   '60462',
#   'Central',
#   'TEC-AC-10000844',
#   'Logitech\xa0Gaming G510s - Keyboard',
#   'Technology',
#   'Accessories',
#   Decimal('339.9600000000'),
#   Decimal('5.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('67.9920000000')),
#  (11607,
#   'CA-2017-146780',
#   datetime.date(2017, 12, 25),
# ...
#   'Binders',
#   Decimal('6.2400000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('3.0576000000')),
#  (12459,
#   'CA-2016-120859',
#   datetime.date(2016, 9, 1),
#   datetime.date(2016, 9, 4),
#   'First Class',
#   'CV-12805',
#   'Cynthia Voltz',
#   'Corporate',
#   'United States',
#   'San Francisco',
#   'California',
#   '94110',
#   'West',
#   'OFF-EN-10001335',
#   'White Business Envelopes with Contemporary Seam, Recycled White Business Envelopes',
#   'Office Supplies',
#   'Envelopes',
#   Decimal('21.8800000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('10.9400000000')),
#  (12460,
#   'CA-2014-127488',
#   datetime.date(2014, 9, 22),
#   datetime.date(2014, 9, 24),
#   'Second Class',
#   'MS-17365',
#   'Maribeth Schnelling',
#   'Consumer',
#   'United States',
#   'Boca Raton',
#   'Florida',
#   '33433',
#   'South',
#   'OFF-LA-10001613',
#   'Avery File Folder Labels',
#   'Office Supplies',
#   'Labels',
#   Decimal('4.6080000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('1.6704000000')),
#  (12461,
#   'CA-2017-135279',
#   datetime.date(2017, 4, 9),
#   datetime.date(2017, 4, 11),
#   'First Class',
#   'BS-11800',
#   'Bryan Spruell',
#   'Home Office',
#   'United States',
#   'New York City',
#   'New York',
#   '10011',
#   'East',
#   'OFF-LA-10004055',
#   'Color-Coded Legal Exhibit Labels',
#   'Office Supplies',
#   'Labels',
#   Decimal('9.8200000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('4.8118000000')),
#  (12462,
#   'CA-2017-135279',
#   datetime.date(2017, 4, 9),
#   datetime.date(2017, 4, 11),
#   'First Class',
#   'BS-11800',
#   'Bryan Spruell',
#   'Home Office',
#   'United States',
#   'New York City',
#   'New York',
#   '10011',
#   'East',
#   'OFF-AR-10004344',
#   'Bulldog Vacuum Base Pencil Sharpener',
#   'Office Supplies',
#   'Art',
#   Decimal('35.9700000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('9.7119000000')),
#  (12463,
#   'CA-2017-135279',
#   datetime.date(2017, 4, 9),
#   datetime.date(2017, 4, 11),
#   'First Class',
#   'BS-11800',
#   'Bryan Spruell',
#   'Home Office',
#   'United States',
#   'New York City',
#   'New York',
#   '10011',
#   'East',
#   'OFF-PA-10004621',
#   'Xerox 212',
#   'Office Supplies',
#   'Paper',
#   Decimal('12.9600000000'),
#   Decimal('2.0000000000'),
#   Decimal('0E-10'),
#   Decimal('6.2208000000')),
#  (12464,
#   'CA-2017-135279',
#   datetime.date(2017, 4, 9),
#   datetime.date(2017, 4, 11),
#   'First Class',
#   'BS-11800',
#   'Bryan Spruell',
#   'Home Office',
#   'United States',
#   'New York City',
#   'New York',
#   '10011',
#   'East',
#   'OFF-PA-10001281',
#   'Computer Printout Paper with Letter-Trim Fine Perforations',
#   'Office Supplies',
#   'Paper',
#   Decimal('191.6000000000'),
#   Decimal('4.0000000000'),
#   Decimal('0E-10'),
#   Decimal('91.9680000000')),
#  (12465,
#   'CA-2017-135279',
#   datetime.date(2017, 4, 9),
#   datetime.date(2017, 4, 11),
#   'First Class',
#   'BS-11800',
#   'Bryan Spruell',
#   'Home Office',
#   'United States',
#   'New York City',
#   'New York',
#   '10011',
#   'East',
#   'OFF-LA-10001613',
#   'Avery File Folder Labels',
#   'Office Supplies',
#   'Labels',
#   Decimal('8.6400000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('4.2336000000')),
#  (12466,
#   'CA-2017-135279',
#   datetime.date(2017, 4, 9),
#   datetime.date(2017, 4, 11),
#   'First Class',
#   'BS-11800',
#   'Bryan Spruell',
#   'Home Office',
#   'United States',
#   'New York City',
#   'New York',
#   '10011',
#   'East',
#   'OFF-ST-10001097',
#   'Office Impressions Heavy Duty Welded Shelving & Multimedia Storage Drawers',
#   'Office Supplies',
#   'Storage',
#   Decimal('501.8100000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('0E-10')),
#  (12467,
#   'CA-2014-115791',
#   datetime.date(2014, 1, 16),
#   datetime.date(2014, 1, 18),
#   'Second Class',
#   'DL-13315',
#   'Delfina Latchford',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19134',
#   'East',
#   'FUR-FU-10001095',
#   'DAX Black Cherry Wood-Tone Poster Frame',
#   'Furniture',
#   'Furnishings',
#   Decimal('127.1040000000'),
#   Decimal('6.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('28.5984000000')),
#  (12468,
#   'CA-2014-115791',
#   datetime.date(2014, 1, 16),
#   datetime.date(2014, 1, 18),
#   'Second Class',
#   'DL-13315',
#   'Delfina Latchford',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19134',
#   'East',
#   'TEC-PH-10004614',
#   'AT&T 841000 Phone',
#   'Technology',
#   'Phones',
#   Decimal('124.2000000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.4000000000'),
#   Decimal('-31.0500000000')),
#  (12469,
#   'CA-2014-115791',
#   datetime.date(2014, 1, 16),
#   datetime.date(2014, 1, 18),
#   'Second Class',
#   'DL-13315',
#   'Delfina Latchford',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19134',
#   'East',
#   'OFF-BI-10001575',
#   'GBC Linen Binding Covers',
#   'Office Supplies',
#   'Binders',
#   Decimal('18.5880000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.7000000000'),
#   Decimal('-13.6312000000')),
#  (12470,
#   'CA-2014-115791',
#   datetime.date(2014, 1, 16),
#   datetime.date(2014, 1, 18),
#   'Second Class',
#   'DL-13315',
#   'Delfina Latchford',
#   'Consumer',
#   'United States',
#   'Philadelphia',
#   'Pennsylvania',
#   '19134',
#   'East',
#   'OFF-LA-10001074',
#   'Round Specialty Laser Printer Labels',
#   'Office Supplies',
#   'Labels',
#   Decimal('30.0720000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('10.1493000000')),
#  (12471,
#   'US-2017-103247',
#   datetime.date(2017, 10, 5),
#   datetime.date(2017, 10, 8),
#   'Second Class',
#   'PO-19195',
#   'Phillina Ober',
#   'Home Office',
#   'United States',
#   'New York City',
#   'New York',
#   '10011',
#   'East',
#   'TEC-PH-10003555',
#   'Motorola HK250 Universal Bluetooth Headset',
#   'Technology',
#   'Phones',
#   Decimal('160.9300000000'),
#   Decimal('7.0000000000'),
#   Decimal('0E-10'),
#   Decimal('3.2186000000')),
#  (12472,
#   'US-2017-103247',
#   datetime.date(2017, 10, 5),
#   datetime.date(2017, 10, 8),
#   'Second Class',
#   'PO-19195',
#   'Phillina Ober',
#   'Home Office',
#   'United States',
#   'New York City',
#   'New York',
#   '10011',
#   'East',
#   'OFF-BI-10004492',
#   'Tuf-Vin Binders',
#   'Office Supplies',
#   'Binders',
#   Decimal('75.7920000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('25.5798000000')),
#  (12473,
#   'US-2017-100209',
#   datetime.date(2017, 7, 9),
#   datetime.date(2017, 7, 15),
#   'Standard Class',
#   'TD-20995',
#   'Tamara Dahlen',
#   'Consumer',
#   'United States',
#   'Portland',
#   'Oregon',
#   '97206',
#   'West',
#   'OFF-BI-10002012',
#   'Wilson Jones Easy Flow II Sheet Lifters',
#   'Office Supplies',
#   'Binders',
#   Decimal('1.0800000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.7000000000'),
#   Decimal('-0.7920000000')),
#  (12474,
#   'CA-2017-159366',
#   datetime.date(2017, 1, 7),
#   datetime.date(2017, 1, 10),
#   'First Class',
#   'BW-11110',
#   'Bart Watters',
#   'Corporate',
#   'United States',
#   'Detroit',
#   'Michigan',
#   '48205',
#   'Central',
#   'TEC-MA-10000822',
#   'Lexmark MX611dhe Monochrome Laser Printer',
#   'Technology',
#   'Machines',
#   Decimal('3059.9820000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.1000000000'),
#   Decimal('679.9960000000')),
#  (12475,
#   'CA-2016-145499',
#   datetime.date(2016, 5, 30),
#   datetime.date(2016, 5, 31),
#   'First Class',
#   'RW-19690',
#   'Robert Waldorf',
#   'Consumer',
#   'United States',
#   'Wilmington',
#   'North Carolina',
#   '28403',
#   'South',
#   'OFF-BI-10000848',
#   'Angle-D Ring Binders',
#   'Office Supplies',
#   'Binders',
#   Decimal('3.2820000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.7000000000'),
#   Decimal('-2.6256000000')),
#  (12476,
#   'CA-2015-157035',
#   datetime.date(2015, 12, 9),
#   datetime.date(2015, 12, 12),
#   'First Class',
#   'KB-16600',
#   'Ken Brennan',
#   'Corporate',
#   'United States',
#   'Columbus',
#   'Indiana',
#   '47201',
#   'Central',
#   'OFF-PA-10004156',
#   'Xerox 188',
#   'Office Supplies',
#   'Paper',
#   Decimal('34.0200000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('16.6698000000')),
#  (12477,
#   'CA-2016-144939',
#   datetime.date(2016, 10, 3),
#   datetime.date(2016, 10, 8),
#   'Standard Class',
#   'EB-13870',
#   'Emily Burns',
#   'Consumer',
#   'United States',
#   'New York City',
#   'New York',
#   '10035',
#   'East',
#   'FUR-CH-10003199',
#   'Office Star - Contemporary Task Swivel Chair',
#   'Furniture',
#   'Chairs',
#   Decimal('599.2920000000'),
#   Decimal('6.0000000000'),
#   Decimal('0.1000000000'),
#   Decimal('93.2232000000')),
#  (12478,
#   'CA-2014-163419',
#   datetime.date(2014, 11, 11),
#   datetime.date(2014, 11, 14),
#   'Second Class',
#   'TZ-21580',
#   'Tracy Zic',
#   'Consumer',
#   'United States',
#   'Louisville',
#   'Colorado',
#   '80027',
#   'West',
#   'OFF-AR-10000034',
#   'BIC Brite Liner Grip Highlighters, Assorted, 5/Pack',
#   'Office Supplies',
#   'Art',
#   Decimal('3.3920000000'),
#   Decimal('1.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.8056000000')),
#  (12479,
#   'CA-2014-163419',
#   datetime.date(2014, 11, 11),
#   datetime.date(2014, 11, 14),
#   'Second Class',
#   'TZ-21580',
#   'Tracy Zic',
#   'Consumer',
#   'United States',
#   'Louisville',
#   'Colorado',
#   '80027',
#   'West',
#   'TEC-PH-10000560',
#   'Samsung Galaxy S III - 16GB - pebble blue (T-Mobile)',
#   'Technology',
#   'Phones',
#   Decimal('559.9840000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('55.9984000000')),
#  (12480,
#   'CA-2014-163419',
#   datetime.date(2014, 11, 11),
#   datetime.date(2014, 11, 14),
#   'Second Class',
#   'TZ-21580',
#   'Tracy Zic',
#   'Consumer',
#   'United States',
#   'Louisville',
#   'Colorado',
#   '80027',
#   'West',
#   'FUR-CH-10000665',
#   'Global Airflow Leather Mesh Back Chair, Black',
#   'Furniture',
#   'Chairs',
#   Decimal('603.9200000000'),
#   Decimal('5.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('75.4900000000')),
#  (12481,
#   'CA-2017-100314',
#   datetime.date(2017, 9, 29),
#   datetime.date(2017, 10, 5),
#   'Standard Class',
#   'AS-10630',
#   'Ann Steele',
#   'Home Office',
#   'United States',
#   'Pasadena',
#   'Texas',
#   '77506',
#   'Central',
#   'OFF-LA-10001569',
#   'Avery 499',
#   'Office Supplies',
#   'Labels',
#   Decimal('7.9680000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('2.5896000000')),
#  (12482,
#   'CA-2017-100314',
#   datetime.date(2017, 9, 29),
#   datetime.date(2017, 10, 5),
#   'Standard Class',
#   'AS-10630',
#   'Ann Steele',
#   'Home Office',
#   'United States',
#   'Pasadena',
#   'Texas',
#   '77506',
#   'Central',
#   'OFF-EN-10000461',
#   '#10- 4 1/8" x 9 1/2" Recycled Envelopes',
#   'Office Supplies',
#   'Envelopes',
#   Decimal('27.9680000000'),
#   Decimal('4.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('9.4392000000')),
#  (12483,
#   'CA-2017-100314',
#   datetime.date(2017, 9, 29),
#   datetime.date(2017, 10, 5),
#   'Standard Class',
#   'AS-10630',
#   'Ann Steele',
#   'Home Office',
#   'United States',
#   'Pasadena',
#   'Texas',
#   '77506',
#   'Central',
#   'TEC-MA-10003066',
#   'Wasp CCD Handheld Bar Code Reader',
#   'Technology',
#   'Machines',
#   Decimal('336.5100000000'),
#   Decimal('3.0000000000'),
#   Decimal('0.4000000000'),
#   Decimal('44.8680000000')),
#  (12484,
#   'CA-2015-146829',
#   datetime.date(2015, 3, 10),
#   datetime.date(2015, 3, 10),
#   'Same Day',
#   'TS-21340',
#   'Toby Swindell',
#   'Consumer',
#   'United States',
#   'Houston',
#   'Texas',
#   '77041',
#   'Central',
#   'OFF-BI-10004022',
#   'Acco Suede Grain Vinyl Round Ring Binder',
#   'Office Supplies',
#   'Binders',
#   Decimal('1.1120000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.8000000000'),
#   Decimal('-1.8904000000')),
#  (12485,
#   'CA-2017-167899',
#   datetime.date(2017, 5, 21),
#   datetime.date(2017, 5, 26),
#   'Standard Class',
#   'JG-15805',
#   'John Grady',
#   'Corporate',
#   'United States',
#   'Auburn',
#   'New York',
#   '13021',
#   'East',
#   'FUR-FU-10004071',
#   'Luxo Professional Magnifying Clamp-On Fluorescent Lamps',
#   'Furniture',
#   'Furnishings',
#   Decimal('520.0500000000'),
#   Decimal('5.0000000000'),
#   Decimal('0E-10'),
#   Decimal('72.8070000000')),
#  (12486,
#   'CA-2017-167899',
#   datetime.date(2017, 5, 21),
#   datetime.date(2017, 5, 26),
#   'Standard Class',
#   'JG-15805',
#   'John Grady',
#   'Corporate',
#   'United States',
#   'Auburn',
#   'New York',
#   '13021',
#   'East',
#   'OFF-AR-10001988',
#   'Bulldog Table or Wall-Mount Pencil Sharpener',
#   'Office Supplies',
#   'Art',
#   Decimal('17.9700000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('5.2113000000')),
#  (12487,
#   'CA-2015-153549',
#   datetime.date(2015, 3, 29),
#   datetime.date(2015, 3, 31),
#   'Second Class',
#   'SL-20155',
#   'Sara Luxemburg',
#   'Home Office',
#   'United States',
#   'Jacksonville',
#   'Florida',
#   '32216',
#   'South',
#   'FUR-CH-10004086',
#   'Hon 4070 Series Pagoda Armless Upholstered Stacking Chairs',
#   'Furniture',
#   'Chairs',
#   Decimal('1166.9200000000'),
#   Decimal('5.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('131.2785000000')),
#  (12488,
#   'CA-2016-110023',
#   datetime.date(2016, 9, 9),
#   datetime.date(2016, 9, 11),
#   'First Class',
#   'TS-21610',
#   'Troy Staebel',
#   'Consumer',
#   'United States',
#   'New York City',
#   'New York',
#   '10024',
#   'East',
#   'OFF-BI-10001036',
#   'Cardinal EasyOpen D-Ring Binders',
#   'Office Supplies',
#   'Binders',
#   Decimal('14.6240000000'),
#   Decimal('2.0000000000'),
#   Decimal('0.2000000000'),
#   Decimal('5.4840000000')),
#  (12489,
#   'CA-2016-105585',
#   datetime.date(2016, 8, 26),
#   datetime.date(2016, 8, 27),
#   'First Class',
#   'RF-19735',
#   'Roland Fjeld',
#   'Consumer',
#   'United States',
#   'San Jose',
#   'California',
#   '95123',
#   'West',
#   'OFF-FA-10002983',
#   'Advantus SlideClip Paper Clips',
#   'Office Supplies',
#   'Fasteners',
#   Decimal('10.2300000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('4.9104000000')),
#  (12490,
#   'CA-2016-105585',
#   datetime.date(2016, 8, 26),
#   datetime.date(2016, 8, 27),
#   'First Class',
#   'RF-19735',
#   'Roland Fjeld',
#   'Consumer',
#   'United States',
#   'San Jose',
#   'California',
#   '95123',
#   'West',
#   'OFF-PA-10003625',
#   'Xerox 1979',
#   'Office Supplies',
#   'Paper',
#   Decimal('154.9000000000'),
#   Decimal('5.0000000000'),
#   Decimal('0E-10'),
#   Decimal('69.7050000000')),
#  (12491,
#   'CA-2014-117639',
#   datetime.date(2014, 5, 21),
#   datetime.date(2014, 5, 25),
#   'Standard Class',
#   'MW-18235',
#   'Mitch Willingham',
#   'Corporate',
#   'United States',
#   'Virginia Beach',
#   'Virginia',
#   '23464',
#   'South',
#   'OFF-BI-10003925',
#   'Fellowes PB300 Plastic Comb Binding Machine',
#   'Office Supplies',
#   'Binders',
#   Decimal('2715.9300000000'),
#   Decimal('7.0000000000'),
#   Decimal('0E-10'),
#   Decimal('1276.4871000000')),
#  (12492,
#   'CA-2014-117639',
#   datetime.date(2014, 5, 21),
#   datetime.date(2014, 5, 25),
#   'Standard Class',
#   'MW-18235',
#   'Mitch Willingham',
#   'Corporate',
#   'United States',
#   'Virginia Beach',
#   'Virginia',
#   '23464',
#   'South',
#   'TEC-PH-10001530',
#   'Plantronics Voyager Pro Legend',
#   'Technology',
#   'Phones',
#   Decimal('617.9700000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('173.0316000000')),
#  (12493,
#   'CA-2015-162537',
#   datetime.date(2015, 10, 28),
#   datetime.date(2015, 11, 3),
#   'Standard Class',
#   'RD-19585',
#   'Rob Dowd',
#   'Consumer',
#   'United States',
#   'Henderson',
#   'Kentucky',
#   '42420',
#   'South',
#   'OFF-EN-10003862',
#   'Laser & Ink Jet Business Envelopes',
#   'Office Supplies',
#   'Envelopes',
#   Decimal('10.6700000000'),
#   Decimal('1.0000000000'),
#   Decimal('0E-10'),
#   Decimal('4.9082000000')),
#  (12494,
#   'CA-2015-162537',
#   datetime.date(2015, 10, 28),
#   datetime.date(2015, 11, 3),
#   'Standard Class',
#   'RD-19585',
#   'Rob Dowd',
#   'Consumer',
#   'United States',
#   'Henderson',
#   'Kentucky',
#   '42420',
#   'South',
#   'OFF-ST-10004258',
#   'Portable Personal File Box',
#   'Office Supplies',
#   'Storage',
#   Decimal('36.6300000000'),
#   Decimal('3.0000000000'),
#   Decimal('0E-10'),
#   Decimal('9.8901000000')),
#  (12495,
#   'CA-2015-162537',
#   datetime.date(2015, 10, 28),
#   datetime.date(2015, 11, 3),
#   'Standard Class',
#   'RD-19585',
#   'Rob Dowd',
#   'Consumer',
#   'United States',
#   'Henderson',
#   'Kentucky',
#   '42420',
#   'South',
#   'FUR-FU-10002885',
#   'Magna Visual Magnetic Picture Hangers',
#   'Furniture',
#   'Furnishings',
#   Decimal('24.1000000000'),
#   Decimal('5.0000000000'),
#   Decimal('0E-10'),
#   Decimal('9.1580000000')),
#  ...]

# %%
df = pd.DataFrame(df,columns=columns)

# %%
df
# Out:
#       id_venda_item        id_venda  data_venda  data_envio      tipo_envio  \
# 0             11497  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 1             11498  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 2             11499  CA-2016-138688  2016-06-12  2016-06-16    Second Class
# 3             11500  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# 4             11501  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# ...             ...             ...         ...         ...             ...
# 9989          21486  CA-2014-110422  2014-01-21  2014-01-23    Second Class
# 9990          21487  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9991          21488  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9992          21489  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9993          21490  CA-2017-119914  2017-05-04  2017-05-09    Second Class
#
#      id_cliente      nome_cliente   segmento           pais           cidade  \
# 0      CG-12520       Claire Gute   Consumer  United States        Henderson
# 1      CG-12520       Claire Gute   Consumer  United States        Henderson
# 2      DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3      SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4      SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...         ...               ...        ...            ...              ...
# 9989   TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993   CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... codigo_postal regiao       id_produto  \
# 0     ...         42420  South  FUR-BO-10001798
# 1     ...         42420  South  FUR-CH-10000454
# 2     ...         90036   West  OFF-LA-10000240
# 3     ...         33311  South  FUR-TA-10000577
# 4     ...         33311  South  OFF-ST-10000760
# ...   ...           ...    ...              ...
# 9989  ...         33180  South  FUR-FU-10001889
# 9990  ...         92627   West  FUR-FU-10000747
# 9991  ...         92627   West  TEC-PH-10003645
# 9992  ...         92627   West  OFF-PA-10004041
# 9993  ...         92683   West  OFF-AP-10002684
#
#                                       descricao_produto categoria_produto  \
# 0                     Bush Somerset Collection Bookcase         Furniture
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...         Furniture
# 2     Self-Adhesive Address Labels for Typewriters b...   Office Supplies
# 3         Bretford CR4500 Series Slim Rectangular Table         Furniture
# 4                        Eldon Fold 'N Roll Cart System   Office Supplies
# ...                                                 ...               ...
# 9989                             Ultra Door Pull Handle         Furniture
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...         Furniture
# 9991                              Aastra 57i VoIP phone        Technology
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   Office Supplies
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...   Office Supplies
#
#      subcategoria_produto     valor_venda quantidade_vendida      desconto  \
# 0               Bookcases  261.9600000000       2.0000000000         0E-10
# 1                  Chairs  731.9400000000       3.0000000000         0E-10
# 2                  Labels   14.6200000000       2.0000000000         0E-10
# 3                  Tables  957.5775000000       5.0000000000  0.4500000000
# 4                 Storage   22.3680000000       2.0000000000  0.2000000000
# ...                   ...             ...                ...           ...
# 9989          Furnishings   25.2480000000       3.0000000000  0.2000000000
# 9990          Furnishings   91.9600000000       2.0000000000         0E-10
# 9991               Phones  258.5760000000       2.0000000000  0.2000000000
# 9992                Paper   29.6000000000       4.0000000000         0E-10
# 9993           Appliances  243.1600000000       2.0000000000         0E-10
#
#                margem
# 0       41.9136000000
# 1      219.5820000000
# 2        6.8714000000
# 3     -383.0310000000
# 4        2.5164000000
# ...               ...
# 9989     4.1028000000
# 9990    15.6332000000
# 9991    19.3932000000
# 9992    13.3200000000
# 9993    72.9480000000
#
# [9994 rows x 21 columns]
